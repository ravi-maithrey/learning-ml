# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt

# %%
DATA_PATH = "~/Documents/ml-25m"
MOVIES_PATH = DATA_PATH+"/movies.csv"
RATINGS_PATH = DATA_PATH+"/ratings.csv"
LINKS_PATH = DATA_PATH+"/links.csv"

# %%
movies = pd.read_csv(MOVIES_PATH)
ratings = pd.read_csv(RATINGS_PATH)
links = pd.read_csv(LINKS_PATH)

# %%
movies.head(10)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 5                        Action|Crime|Thriller
# 6                               Comedy|Romance
# 7                           Adventure|Children
# 8                                       Action
# 9                    Action|Adventure|Thriller

# %%
ratings.head()
links.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
ratings[ratings["userId"] == 3][0:2]
# Out:
#      userId  movieId  rating   timestamp
# 254       3        1     4.0  1439472215
# 255       3       29     4.5  1484754967

# %%
movies.info(), ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62423 entries, 0 to 62422
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  62423 non-null  int64
#  1   title    62423 non-null  object
#  2   genres   62423 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 1.4+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000095 entries, 0 to 25000094
# Data columns (total 4 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   userId     int64
#  1   movieId    int64
#  2   rating     float64
#  3   timestamp  int64
# dtypes: float64(1), int64(3)
# memory usage: 762.9 MB
# (None, None)

# %%
#removing genre from movie dataset as it is extraneous and we have other datasets with it
movies = movies.loc[:,["movieId", "title"]]

#removing timestamp from ratings
ratings = ratings.loc[:,["userId", "movieId", "rating"]]

# %%
#merging both these to get master dataset
full_data = pd.merge(movies, ratings)
full_data.head(10)
# Out:
#    movieId             title  userId  rating
# 0        1  Toy Story (1995)       2     3.5
# 1        1  Toy Story (1995)       3     4.0
# 2        1  Toy Story (1995)       4     3.0
# 3        1  Toy Story (1995)       5     4.0
# 4        1  Toy Story (1995)       8     4.0
# 5        1  Toy Story (1995)      10     3.5
# 6        1  Toy Story (1995)      12     4.0
# 7        1  Toy Story (1995)      13     4.0
# 8        1  Toy Story (1995)      18     3.0
# 9        1  Toy Story (1995)      26     3.0

# %%
pivot = full_data.pivot_table(index=["userId"], columns=["title"], values=["rating"])
pivot.head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-09cc7a98b3ce> in <module>
# ----> 1 pivot = full_data.pivot_table(index=["userId"], columns=["title"], values=["rating"])
#       2 pivot.head(10)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#    7029         from pandas.core.reshape.pivot import pivot_table
#    7030
# -> 7031         return pivot_table(
#    7032             self,
#    7033             values=values,
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#     111
#     112     grouped = data.groupby(keys, observed=observed)
# --> 113     agged = grouped.agg(aggfunc)
#     114     if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#     115         agged = agged.dropna(how="all")
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     943         func = maybe_mangle_lambdas(func)
#     944
# --> 945         result, how = aggregate(self, func, *args, **kwargs)
#     946         if how is None:
#     947             return result
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/aggregation.py in aggregate(obj, arg, *args, **kwargs)
#     577
#     578     if isinstance(arg, str):
# --> 579         return obj._try_aggregate_string_function(arg, *args, **kwargs), None
#     580     elif is_dict_like(arg):
#     581         arg = cast(AggFuncTypeDict, arg)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/base.py in _try_aggregate_string_function(self, arg, *args, **kwargs)
#     313         if f is not None:
#     314             if callable(f):
# --> 315                 return f(*args, **kwargs)
#     316
#     317             # people may try to aggregate on a non-callable attribute
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in mean(self, numeric_only)
#    1494         Name: B, dtype: float64
#    1495         """
# -> 1496         return self._cython_agg_general(
#    1497             "mean",
#    1498             alt=lambda x, axis: Series(x).mean(numeric_only=numeric_only),
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/generic.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#    1013         self, how: str, alt=None, numeric_only: bool = True, min_count: int = -1
#    1014     ) -> DataFrame:
# -> 1015         agg_mgr = self._cython_agg_blocks(
#    1016             how, alt=alt, numeric_only=numeric_only, min_count=min_count
#    1017         )
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/generic.py in _cython_agg_blocks(self, how, alt, numeric_only, min_count)
#    1116         #  continue and exclude the block
#    1117         # NotImplementedError -> "ohlc" with wrong dtype
# -> 1118         new_mgr = data.apply(blk_func, ignore_failures=True)
#    1119
#    1120         if not len(new_mgr):
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     423             try:
#     424                 if callable(f):
# --> 425                     applied = b.apply(f, **kwargs)
#     426                 else:
#     427                     applied = getattr(b, f)(**kwargs)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/internals/blocks.py in apply(self, func, **kwargs)
#     376         """
#     377         with np.errstate(all="ignore"):
# --> 378             result = func(self.values, **kwargs)
#     379
#     380         return self._split_op_result(result)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/generic.py in blk_func(bvalues)
#    1095
#    1096             try:
# -> 1097                 result = self.grouper._cython_operation(
#    1098                     "aggregate", bvalues, how, axis=1, min_count=min_count
#    1099                 )
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/ops.py in _cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     610                     "arity of more than 1 is not supported for the 'how' argument"
#     611                 )
# --> 612             out_shape = (self.ngroups,) + values.shape[1:]
#     613
#     614         func, values = self._get_cython_func_and_vals(kind, how, values, is_numeric)
#
# pandas/_libs/properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/ops.py in ngroups(self)
#     327     @cache_readonly
#     328     def ngroups(self) -> int:
# --> 329         return len(self.result_index)
#     330
#     331     @property
#
# pandas/_libs/properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/ops.py in result_index(self)
#     340             return self.groupings[0].result_index.rename(self.names[0])
#     341
# --> 342         codes = self.reconstructed_codes
#     343         levels = [ping.result_index for ping in self.groupings]
#     344         return MultiIndex(
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/ops.py in reconstructed_codes(self)
#     332     def reconstructed_codes(self) -> List[np.ndarray]:
#     333         codes = self.codes
# --> 334         comp_ids, obs_ids, _ = self.group_info
#     335         return decons_obs_group_ids(comp_ids, obs_ids, self.shape, codes, xnull=True)
#     336
#
# pandas/_libs/properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/ops.py in group_info(self)
#     298     @cache_readonly
#     299     def group_info(self):
# --> 300         comp_ids, obs_group_ids = self._get_compressed_codes()
#     301
#     302         ngroups = len(obs_group_ids)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/ops.py in _get_compressed_codes(self)
#     319         if len(all_codes) > 1:
#     320             group_index = get_group_index(all_codes, self.shape, sort=True, xnull=True)
# --> 321             return compress_group_index(group_index, sort=self.sort)
#     322
#     323         ping = self.groupings[0]
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/sorting.py in compress_group_index(group_index, sort)
#     605
#     606     if sort and len(obs_group_ids) > 0:
# --> 607         obs_group_ids, comp_ids = _reorder_by_uniques(obs_group_ids, comp_ids)
#     608
#     609     return ensure_int64(comp_ids), ensure_int64(obs_group_ids)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/sorting.py in _reorder_by_uniques(uniques, labels)
#     612 def _reorder_by_uniques(uniques, labels):
#     613     # sorter is index where elements ought to go
# --> 614     sorter = uniques.argsort()
#     615
#     616     # reverse_indexer is where elements came from
#
# KeyboardInterrupt:
