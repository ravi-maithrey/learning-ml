# %%
#importing required libraries
from sklearn.linear_model import LinearRegression
import pandas as pd
import numpy as np

# %%
#loading data
DATA_PATH = "~/Documents/ISLR"
BOSTON_PATH = DATA_PATH+"/Boston.csv"
AUTO_PATH = DATA_PATH+"/Auto.csv"

# %%
#checking data 
boston = pd.read_csv(BOSTON_PATH,index_col=0)
boston.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    lstat  medv
# 1   4.98  24.0
# 2   9.14  21.6
# 3   4.03  34.7
# 4   2.94  33.4
# 5   5.33  36.2

# %%
boston.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'lstat', 'medv'],
#       dtype='object')

# %%
list(boston.medv)
# Out:
# [24.0,
#  21.6,
#  34.7,
#  33.4,
#  36.2,
#  28.7,
#  22.9,
#  27.1,
#  16.5,
#  18.9,
#  15.0,
#  18.9,
#  21.7,
#  20.4,
#  18.2,
#  19.9,
#  23.1,
#  17.5,
#  20.2,
#  18.2,
#  13.6,
#  19.6,
#  15.2,
#  14.5,
#  15.6,
#  13.9,
#  16.6,
#  14.8,
#  18.4,
#  21.0,
#  12.7,
#  14.5,
#  13.2,
#  13.1,
#  13.5,
#  18.9,
#  20.0,
#  21.0,
#  24.7,
#  30.8,
#  34.9,
#  26.6,
#  25.3,
#  24.7,
#  21.2,
#  19.3,
#  20.0,
#  16.6,
#  14.4,
#  19.4,
#  19.7,
#  20.5,
#  25.0,
#  23.4,
#  18.9,
#  35.4,
#  24.7,
#  31.6,
#  23.3,
#  19.6,
#  18.7,
#  16.0,
#  22.2,
#  25.0,
#  33.0,
#  23.5,
#  19.4,
#  22.0,
#  17.4,
#  20.9,
#  24.2,
#  21.7,
#  22.8,
#  23.4,
#  24.1,
#  21.4,
#  20.0,
#  20.8,
#  21.2,
#  20.3,
#  28.0,
#  23.9,
#  24.8,
#  22.9,
#  23.9,
#  26.6,
#  22.5,
#  22.2,
#  23.6,
#  28.7,
#  22.6,
#  22.0,
#  22.9,
#  25.0,
#  20.6,
#  28.4,
#  21.4,
#  38.7,
#  43.8,
#  33.2,
#  27.5,
#  26.5,
#  18.6,
#  19.3,
#  20.1,
#  19.5,
#  19.5,
#  20.4,
#  19.8,
#  19.4,
#  21.7,
# ...

# %%
#fitting the lstat and medv columns to a linear regression. this step of having the values in [[]] does the reshape for us
y = boston[["medv"]]
X = boston[["lstat"]]
# we reshape the values as this class takes only 2D arrays
#X = X.reshape(len(X),1)
#y = y.reshape(len(y),1)
linear_reg = LinearRegression().fit(X, y)
y_pred = linear_reg.predict(X)

# %%
linear_reg.coef_
# Out:
# array([[-0.95004935]])

# %%
linear_reg.predict([[5]])
# Out:
# array([[29.80359411]])

# %%
import matplotlib.pyplot as plt
plt.scatter(X,y, color="black")
plt.plot(X, y_pred, color="blue")

# %%
#trying out multiple linear regression
X = boston[['lstat','age']]
y = boston[["medv"]]

multi_linear_reg = LinearRegression().fit(X,y)

# %%
multi_linear_reg.coef_
# Out:
# array([[-1.03206856,  0.03454434]])

# %%
y_pred = multi_linear_reg.predict(X)
y_pred
# Out:
# array([[30.33534996],
#        [26.51520217],
#        [31.1741833 ],
#        [31.77060966],
#        [29.59413824],
#        [29.87343599],
#        [22.69480123],
#        [16.77835846],
#        [ 5.78738226],
#        [18.54174677],
#        [15.37448952],
#        [22.39093635],
#        [18.35619259],
#        [26.83271432],
#        [25.55273367],
#        [26.43289492],
#        [27.4438985 ],
#        [20.90458716],
#        [22.42220181],
#        [23.98185866],
#        [14.91747893],
#        [22.03060729],
#        [17.07015286],
#        [16.15967133],
#        [19.6506652 ],
#        [19.14375835],
#        [21.05717887],
#        [18.45615301],
#        [23.27326847],
#        [23.87429989],
#        [13.14863324],
#        [23.21902031],
#        [ 7.45677638],
#        [17.56601454],
#        [15.57783234],
#        [25.58826072],
#        [23.5678806 ],
#        [25.60510927],
#        [23.811145  ],
#        [29.51729092],
#        [31.72506532],
# ...

# %%
#multi linear prediction using full data except medv
X = boston.drop("medv", axis=1)
y = boston[["medv"]]

full_multi_linear_reg = LinearRegression().fit(X,y)

# %%
full_multi_linear_reg.coef_
# Out:
# array([[-1.21388618e-01,  4.69634633e-02,  1.34676947e-02,
#          2.83999338e+00, -1.87580220e+01,  3.65811904e+00,
#          3.61071055e-03, -1.49075365e+00,  2.89404521e-01,
#         -1.26819813e-02, -9.37532900e-01, -5.52019101e-01]])

# %%
y_pred = full_multi_linear_reg.predict(X)
y_pred
# Out:
# array([[30.03373805],
#        [25.05683368],
#        [30.60818602],
#        [28.67717948],
#        [27.928791  ],
#        [25.39316857],
#        [22.80496155],
#        [19.19898495],
#        [11.07897982],
#        [18.71966912],
#        [18.62438629],
#        [21.39246353],
#        [20.60745482],
#        [19.54258612],
#        [19.42338826],
#        [19.29854778],
#        [20.56134548],
#        [16.87747529],
#        [17.09180043],
#        [18.43760689],
#        [12.52394623],
#        [17.63469278],
#        [15.59842603],
#        [13.63779912],
#        [15.57390124],
#        [14.14580816],
#        [15.56515976],
#        [15.35858528],
#        [19.5109376 ],
#        [20.88646225],
#        [11.52648291],
#        [18.19763703],
#        [ 9.85998433],
#        [14.49395604],
#        [14.83212976],
#        [23.83455965],
#        [22.48819096],
#        [23.07938508],
#        [22.83020538],
#        [31.43055097],
#        [34.26922099],
# ...

# %%
auto = pd.read_csv(AUTO_PATH)
auto.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0        130    3504          12.0    70
# 1  15.0          8         350.0        165    3693          11.5    70
# 2  18.0          8         318.0        150    3436          11.0    70
# 3  16.0          8         304.0        150    3433          12.0    70
# 4  17.0          8         302.0        140    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
X = [value for value in auto['horsepower'] if value != "?"]
y = [value for value in auto['horsepower'] if value != "?"]

print(len(X),len(y))
# Out:
# 392 392

# %%
#convert into np.array for proper array
X_array = np.array(X)
y_array = np.array(y)
#convert the array into float
X_float = X_array.astype(float)
y_float = y_array.astype(float)
#reshaping our list data to 2d array for sklearn
X_train_auto = X_float.reshape(-1,1)
y_train_auto = y_float.reshape(-1,1)
#training
linear_reg_auto = LinearRegression().fit(X_train_auto,y_train_auto)

# %%
y_prediction = linear_reg_auto.predict(X_train_auto)

# %%
plt.scatter(X,y, color="black")
plt.plot(X, y_prediction, color="blue")
